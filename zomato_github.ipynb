# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("zomato_1.csv",encoding = "ISO-8859-1")

# %%
df.shape
# Out:
# (9551, 21)

# %%
pd.set_option("max_columns",40)

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.duplicated().sum()
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.dropna()
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
# Restaurant ID           9551 non-null int64
# Restaurant Name         9551 non-null object
# Country Code            9551 non-null int64
# City                    9551 non-null object
# Address                 9551 non-null object
# Locality                9551 non-null object
# Locality Verbose        9551 non-null object
# Longitude               9551 non-null float64
# Latitude                9551 non-null float64
# Cuisines                9542 non-null object
# Average Cost for two    9551 non-null int64
# Currency                9551 non-null object
# Has Table booking       9551 non-null object
# Has Online delivery     9551 non-null object
# Is delivering now       9551 non-null object
# Switch to order menu    9551 non-null object
# Price range             9551 non-null int64
# Aggregate rating        9551 non-null float64
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
dfc=df.loc[df["City"]=="New Delhi"].reset_index(drop=True)
dfc
# Out:
#       Restaurant ID       Restaurant Name  Country Code       City  \
# 0          18287358            Food Cloud             1  New Delhi
# 1          18216944             Burger.in             1  New Delhi
# 2            313333       Days of the Raj             1  New Delhi
# 3          18384127        Dilli Ka Dhaba             1  New Delhi
# 4               582             Govardhan             1  New Delhi
# ...             ...                   ...           ...        ...
# 5468       18445274          Motu N Patlu             1  New Delhi
# 5469       18168147        S.K. Fast Food             1  New Delhi
# 5470       18429375    Sufiyan Restaurant             1  New Delhi
# 5471         310479       The Relax Point             1  New Delhi
# 5472       18212160  Zareen's Dastarkhwan             1  New Delhi
#
#                                                 Address     Locality  \
# 0                                 Aaya Nagar, New Delhi   Aaya Nagar
# ...

# %%
dfc.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   5.473000e+03        5473.0  5473.000000  5473.000000
# mean    8.275258e+06           1.0    73.903792    27.398205
# std     9.038827e+06           0.0    15.596506     5.778869
# min     5.300000e+01           1.0     0.000000     0.000000
# 25%     9.588000e+03           1.0    77.139505    28.557430
# 50%     3.113310e+05           1.0    77.204210    28.621372
# 75%     1.835680e+07           1.0    77.240761    28.654577
# max     1.850062e+07           1.0    77.339139    35.000000
#
#        Average Cost for two  Price range  Aggregate rating        Votes
# count           5473.000000  5473.000000       5473.000000  5473.000000
# mean             596.088069     1.621597          2.438845   114.807236
# std              635.311854     0.820218          1.500079   353.842279
# min               50.000000     1.000000          0.000000     0.000000
# ...

# %%
dfc=dfc.drop(['Restaurant ID',"Country Code","Currency"],axis=1)

# %%
dfc
# Out:
#            Restaurant Name       City  \
# 0               Food Cloud  New Delhi
# 1                Burger.in  New Delhi
# 2          Days of the Raj  New Delhi
# 3           Dilli Ka Dhaba  New Delhi
# 4                Govardhan  New Delhi
# ...                    ...        ...
# 5468          Motu N Patlu  New Delhi
# 5469        S.K. Fast Food  New Delhi
# 5470    Sufiyan Restaurant  New Delhi
# 5471       The Relax Point  New Delhi
# 5472  Zareen's Dastarkhwan  New Delhi
#
#                                                 Address     Locality  \
# 0                                 Aaya Nagar, New Delhi   Aaya Nagar
# 1           84, Near Honda Showroom, Adchini, New Delhi      Adchini
# 2     81/3, 1st Floor, Qutub Residency, Adchini, New...      Adchini
# 3     66 A, Ground Floor, Sri Aurobindo Marg, Adchin...      Adchini
# 4     84, Adjacent Hero Motor Bike Showroom, Main Me...      Adchini
# ...                                                 ...          ...
# ...

# %%
dfc.describe()
# Out:
#          Longitude     Latitude  Average Cost for two  Price range  \
# count  5473.000000  5473.000000           5473.000000  5473.000000
# mean     73.903792    27.398205            596.088069     1.621597
# std      15.596506     5.778869            635.311854     0.820218
# min       0.000000     0.000000             50.000000     1.000000
# 25%      77.139505    28.557430            300.000000     1.000000
# 50%      77.204210    28.621372            400.000000     1.000000
# 75%      77.240761    28.654577            650.000000     2.000000
# max      77.339139    35.000000           8000.000000     4.000000
#
#        Aggregate rating        Votes
# count       5473.000000  5473.000000
# mean           2.438845   114.807236
# std            1.500079   353.842279
# min            0.000000     0.000000
# 25%            0.000000     3.000000
# 50%            3.100000    21.000000
# 75%            3.500000    83.000000
# max            4.900000  7931.000000

# %%
dfc.columns
# Out:
# Index(['Restaurant Name', 'City', 'Address', 'Locality', 'Locality Verbose',
#        'Longitude', 'Latitude', 'Cuisines', 'Average Cost for two',
#        'Has Table booking', 'Has Online delivery', 'Is delivering now',
#        'Switch to order menu', 'Price range', 'Aggregate rating',
#        'Rating color', 'Rating text', 'Votes'],
#       dtype='object')

# %%
dfc['Price range'].unique()
# Out:
# array([2, 1, 3, 4], dtype=int64)

# %%
dfc["Average Cost for two"].unique()
# Out:
# array([ 500,  350, 1500,  400,  450,  300, 1600, 1200,  600,  800,  700,
#        1000,  550,  900,  200,  150,  250,  650, 2200, 1400,  100, 2500,
#        1800, 1300,  750, 1700, 1100, 2000,  850, 1650, 3000,   50, 1450,
#        2400, 1350, 5000,  950, 2800, 1250, 1900, 2100, 1750,  260, 3500,
#        4000, 3650, 4800, 3300, 2700, 1550,  720, 1850, 4500, 6500, 7000,
#        1150, 1050, 2900, 2600, 3200,  120, 4700, 3700, 2300, 1950, 3800,
#        3600, 4100, 4300, 2650, 6000, 5100, 5500, 4400, 4200, 8000],
#       dtype=int64)

# %%
dfc["Votes"].nunique()
# Out:
# 643

# %%
dfc=dfc.rename(columns={"Average Cost for two" : "cost","Aggregate rating":"rating"})

# %%
dfc.groupby("Price range")["cost"].unique()
# Out:
# Price range
# 1    [350, 400, 450, 300, 200, 150, 250, 100, 50, 2...
# 2    [500, 600, 800, 700, 550, 900, 650, 750, 850, ...
# 3    [1500, 1600, 1200, 1000, 1400, 1800, 1300, 170...
# 4    [2200, 2500, 2000, 3000, 2400, 5000, 2800, 210...
# Name: cost, dtype: object

# %%
sns.set(rc={"figure.figsize":(10,8)})
dfc.groupby("Price range")["cost"].hist()
# Out:
# Price range
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# 2    AxesSubplot(0.125,0.125;0.775x0.755)
# 3    AxesSubplot(0.125,0.125;0.775x0.755)
# 4    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: cost, dtype: object

# %%
dfc.groupby("Price range")["cost"].count()
# Out:
# Price range
# 1    3052
# 2    1656
# 3     549
# 4     216
# Name: cost, dtype: int64

# %%
dfc.groupby("rating")["cost"].unique()
# Out:
# rating
# 0.0    [500, 600, 800, 300, 400, 350, 100, 150, 200, ...
# 1.9                                           [250, 500]
# 2.0                                           [400, 900]
# 2.1                  [500, 350, 400, 300, 700, 600, 450]
# 2.2                 [500, 600, 700, 350, 400, 900, 1000]
# 2.3    [750, 600, 700, 1200, 800, 150, 400, 450, 500,...
# 2.4    [800, 100, 1800, 700, 400, 1600, 600, 500, 300...
# 2.5    [300, 500, 600, 550, 1100, 350, 1600, 1000, 70...
# 2.6    [500, 450, 1000, 700, 350, 300, 1800, 550, 200...
# 2.7    [400, 150, 1000, 600, 1500, 700, 450, 500, 300...
# 2.8    [700, 500, 200, 150, 600, 400, 350, 300, 250, ...
# 2.9    [400, 450, 250, 600, 300, 1200, 1000, 700, 800...
# 3.0    [400, 600, 650, 1500, 500, 200, 450, 700, 300,...
# 3.1    [400, 800, 200, 250, 500, 350, 300, 550, 1000,...
# 3.2    [350, 600, 550, 900, 1500, 450, 800, 200, 500,...
# 3.3    [200, 900, 150, 500, 400, 250, 1200, 300, 600,...
# ...

# %%
sns.countplot(dfc['cost'])
sns.countplot(dfc['cost']).set_xticklabels(sns.countplot(dfc['cost']).get_xticklabels(), rotation=90, ha="right")
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Cost of Restuarant')
# Out:
# Text(0.5, 1.0, 'Cost of Restuarant')

# %%
dfc.groupby("rating")["cost"].count()
# Out:
# rating
# 0.0    1425
# 1.9       2
# 2.0       2
# 2.1       8
# 2.2      14
# 2.3      25
# 2.4      46
# 2.5      64
# 2.6     129
# 2.7     170
# 2.8     216
# 2.9     253
# 3.0     318
# 3.1     358
# 3.2     353
# 3.3     332
# 3.4     302
# 3.5     286
# 3.6     251
# 3.7     231
# 3.8     200
# 3.9     160
# 4.0      89
# 4.1      84
# 4.2      64
# 4.3      32
# 4.4      31
# 4.5      11
# 4.6       8
# 4.7       5
# 4.8       1
# 4.9       3
# Name: cost, dtype: int64

# %%
plt.scatter(x="rating",y="cost",data=dfc)

# %%
dfc.head()
# Out:
#    Restaurant Name       City  \
# 0       Food Cloud  New Delhi
# 1        Burger.in  New Delhi
# 2  Days of the Raj  New Delhi
# 3   Dilli Ka Dhaba  New Delhi
# 4        Govardhan  New Delhi
#
#                                              Address    Locality  \
# 0                              Aaya Nagar, New Delhi  Aaya Nagar
# 1        84, Near Honda Showroom, Adchini, New Delhi     Adchini
# 2  81/3, 1st Floor, Qutub Residency, Adchini, New...     Adchini
# 3  66 A, Ground Floor, Sri Aurobindo Marg, Adchin...     Adchini
# 4  84, Adjacent Hero Motor Bike Showroom, Main Me...     Adchini
#
#         Locality Verbose  Longitude   Latitude  \
# 0  Aaya Nagar, New Delhi   0.000000   0.000000
# 1     Adchini, New Delhi  77.196923  28.535382
# 2     Adchini, New Delhi  77.197475  28.535493
# 3     Adchini, New Delhi  77.198033  28.537547
# 4     Adchini, New Delhi  77.196924  28.535523
#
#                               Cuisines  cost Has Table booking  \
# ...

# %%
dfc['Locality'].unique()
# Out:
# array(['Aaya Nagar', 'Adchini', 'Aditya Mega Mall, Karkardooma',
#        'Aerocity', 'Aggarwal City Mall, Pitampura',
#        'Aggarwal City Plaza, Rohini', 'Alaknanda',
#        'Ambience Mall, Vasant Kunj', 'Anand Lok', 'Anand Vihar',
#        'Andaz Delhi, Aerocity', 'Ansal Plaza Mall, Khel Gaon Marg',
#        'ARSS Mall, Paschim Vihar', 'Asaf Ali Road', 'Ashok Vihar Phase 1',
#        'Ashok Vihar Phase 2', 'Ashok Vihar Phase 3', 'Barakhamba Road',
#        'Basant Lok Market, Vasant Vihar', 'Bellagio, Ashok Vihar Phase 2',
#        'Best Western Taurus Hotel, Mahipalpur', 'Bhikaji Cama Place',
#        'Centaur Hotel, Aerocity', 'Chanakyapuri', 'Chander Nagar',
#        'Chandni Chowk', 'Chawri Bazar', 'Chhatarpur', 'Chittaranjan Park',
#        'City Centre Mall, Rohini', 'City Square Mall, Rajouri Garden',
#        'Civil Lines', 'Community Centre, New Friends Colony',
#        'Connaught Place', 'Crescent Square Mall, Rohini',
# ...

# %%
sns.heatmap(dfc.corr(),annot=True)

# %%
dfc.loc[dfc["Votes"]==dfc["Votes"].max()]
# Out:
#        Restaurant Name       City                                 Address  \
# 1434  Hauz Khas Social  New Delhi  9-A & 12, Hauz Khas Village, New Delhi
#
#                Locality              Locality Verbose  Longitude   Latitude  \
# 1434  Hauz Khas Village  Hauz Khas Village, New Delhi  77.194471  28.554285
#
#                                         Cuisines  cost Has Table booking  \
# 1434  Continental, American, Asian, North Indian  1600               Yes
#
#      Has Online delivery Is delivering now Switch to order menu  Price range  \
# 1434                 Yes                No                   No            3
#
#       rating Rating color Rating text  Votes
# 1434     4.3        Green   Very Good   7931

# %%
dfc["Cuisines"].nunique()
# Out:
# 892

# %%
cuisines=dfc.iloc[1:,7]  # in it there is only cuisines values
cuisines
# Out:
# 1                                 Fast Food
# 2        North Indian, Seafood, Continental
# 3                South Indian, North Indian
# 4       South Indian, North Indian, Chinese
# 5                                   Mughlai
#                        ...
# 5468      Lebanese, North Indian, Fast Food
# 5469                                Chinese
# 5470                                Mughlai
# 5471                           North Indian
# 5472                                 Awadhi
# Name: Cuisines, Length: 5472, dtype: object

# %%
new=[]
for i in cuisines:
    c=i.split(",")
    for j in range(0,len(c)):
        new.append(c[j].strip())

# %%
new
# Out:
# ['Fast Food',
#  'North Indian',
#  'Seafood',
#  'Continental',
#  'South Indian',
#  'North Indian',
#  'South Indian',
#  'North Indian',
#  'Chinese',
#  'Mughlai',
#  'Fast Food',
#  'South Indian',
#  'Pizza',
#  'North Indian',
#  'Chinese',
#  'Chinese',
#  'North Indian',
#  'Mediterranean',
#  'Italian',
#  'Continental',
#  'Seafood',
#  'Goan',
#  'Andhra',
#  'Kerala',
#  'Thai',
#  'Parsi',
#  'Finger Food',
#  'North Indian',
#  'Mughlai',
#  'Pizza',
#  'Fast Food',
#  'North Indian',
#  'Chinese',
#  'Continental',
#  'Fast Food',
#  'Italian',
#  'Pizza',
#  'North Indian',
#  'Continental',
#  'Chinese',
#  'Continental',
#  'North Indian',
#  'Fast Food',
#  'Street Food',
#  'South Indian',
#  'Cafe',
#  'North Indian',
#  'Chinese',
#  'Street Food',
#  'Mithai',
#  'North Indian',
#  'Chinese',
#  'Street Food',
#  'South Indian',
#  'Mithai',
#  'North Indian',
#  'Chinese',
#  'Italian',
#  'Pizza',
#  'Fast Food',
#  'Bakery',
#  'Fast Food',
# ...

# %%
new1=pd.DataFrame(new)

# %%
new1[0].value_counts()
# Out:
# North Indian    2425
# Chinese         1638
# Fast Food       1304
# Mughlai          628
# Bakery           465
#                 ...
# Oriya              1
# Sri Lankan         1
# Drinks Only        1
# Deli               1
# Pakistani          1
# Name: 0, Length: 80, dtype: int64

# %%
new1.shape
# Out:
# (10887, 1)

# %%
fig = plt.figure(figsize=(17,5))
rest = sns.countplot(x=0,data=new1, palette = "Set1")
rest.set_xticklabels(rest.get_xticklabels(), rotation=90, ha="right")
plt.ylabel("Frequency",size=15)
plt.xlabel("Restaurant type",size=15)
rest 
plt.title('Restaurant types',fontsize = 20 ,pad=20)
# Out:
# Text(0.5, 1.0, 'Restaurant types')

# %%
new1=new1.rename(columns={0:"cuisines"})

# %%
new1
# Out:
#            cuisines
# 0         Fast Food
# 1      North Indian
# 2           Seafood
# 3       Continental
# 4      South Indian
# ...             ...
# 10882     Fast Food
# 10883       Chinese
# 10884       Mughlai
# 10885  North Indian
# 10886        Awadhi
#
# [10887 rows x 1 columns]
